# %% [markdown]
# # **Project Name**    -  MediBuddy Insurance Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Name-**    THARUNRAJAN

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# MediBuddy is a digital healthcare platform offering inpatient hospitalization, outpatient services, and corporate wellness benefits. It is an award-winning technology platform developed by Medi Assist, aiming to transform the health insurance industry by making policy management seamless, real-time, and virtually paperless. Founded in 2000 and headquartered in Bangalore, Karnataka, India, MediBuddy provides diverse health benefit solutions to various stakeholders in the insurance sector.
#
# This project focuses on analyzing two datasets—one containing pre-health checkup details (age, BMI) and another with personal details (number of children, smoking status, geographic location, etc.). The goal is to investigate key factors influencing insurance costs and develop a predictive machine-learning model to estimate the amount spent with high accuracy.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/tharunrajan10/Labmentix-Intern

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Insurance companies face challenges in accurately determining policy costs due to multiple influencing factors such as age, BMI, smoking habits, number of dependents, and geographic location. These factors affect the likelihood of claims and overall healthcare expenditures. To optimize policy pricing and risk assessment, MediBuddy aims to analyze historical data, identify significant predictors, and implement a machine-learning model to forecast insurance costs effectively.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The primary goal of this project is to optimize insurance policy pricing and improve risk assessment for MediBuddy by analyzing key factors influencing insurance claims. To achieve this, the following business objectives are established:
#
# 1. Assess the Impact of Gender on Policy Extension
#
#     Determine if gender plays a role in risk assessment and policy extension.
#
#     Evaluate whether policies should be structured differently based on gender-related health risks.
#
# 2. Analyze the Average Cost per Policy Cover
#
#     Calculate the average amount spent per policy to gain insights into cost trends.
#
#     Identify factors that contribute to higher or lower policy expenditures.
#
# 3. Determine the Need for Geographic-Based Policy Segmentation
#
#     Analyze if insurance costs vary significantly across different geographic locations.
#
#     Recommend whether separate policies should be created based on location-based risk factors.
#
# 4. Evaluate the Effect of Dependents on Claim Amounts
#
#     Investigate if the number of dependents impacts the total claim amount.
#
#     Assess whether policies should account for family size when determining premiums.
#
# 5. Examine the Relationship Between BMI and Insurance Claims
#
#     Identify whether BMI influences the likelihood of higher claims.
#
#     Suggest policy adjustments or wellness programs based on BMI trends.
#
# 6. Assess the Importance of Smoking Status in Policy Pricing
#
#     Analyze the effect of smoking on insurance claims and costs.
#
#     Determine whether higher premiums should be set for smokers to mitigate risks.
#
# 7. Investigate Age as a Barrier in Insurance Claims
#
#     Study the correlation between age and claim amounts.
#
#     Evaluate if specific age groups are more prone to higher insurance costs.
#
# 8. Explore the Possibility of Health-Based Discounts
#
#     Assess whether discounts can be offered based on BMI and other health indicators.
#
#     Recommend ways to incentivize healthier lifestyles while managing company costs.
#
# By addressing these objectives, MediBuddy can refine its pricing strategies, improve risk assessment, and enhance customer satisfaction through personalized policy offerings.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Datasets
personal_details_df = pd.read_excel("/content/Medibuddy insurance data personal details (1) (2).xlsx")
insurance_price_df = pd.read_excel("/content/Medibuddy Insurance Data Price (1) (2).xlsx")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
personal_details_df.head()
# Out:
#   Policy no.  children smoker     region
# 0  PLC157006         0     no  southwest
# 1  PLC157033         1     no  southwest
# 2  PLC157060         0     no  southwest
# 3  PLC157087         1     no  southwest
# 4  PLC157186         5     no  southwest

# %%
insurance_price_df.head()
# Out:
#   Policy no.  age     sex     bmi  charges in INR
# 0  PLC156898   19  female  27.900     16884.92400
# 1  PLC156907   18    male  33.770      1725.55230
# 2  PLC156916   28    male  33.000      4449.46200
# 3  PLC156925   33    male  22.705     21984.47061
# 4  PLC156934   32    male  28.880      3866.85520

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print("Personal_details file :",personal_details_df.shape)
print("Insurance_price file :",insurance_price_df.shape)
# Out:
# Personal_details file : (1338, 4)
# Insurance_price file : (1338, 5)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
personal_details_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Policy no.  1338 non-null   object
#  1   children    1338 non-null   int64
#  2   smoker      1338 non-null   object
#  3   region      1338 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 41.9+ KB

# %%
insurance_price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Policy no.      1338 non-null   object
#  1   age             1338 non-null   int64
#  2   sex             1338 non-null   object
#  3   bmi             1338 non-null   float64
#  4   charges in INR  1338 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 52.4+ KB

# %% [markdown]
# #### Duplicate Values

# %%
personal_details_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
insurance_price_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
personal_details_df.isnull().sum()
# Out:
# Policy no.    0
# children      0
# smoker        0
# region        0
# dtype: int64

# %%
insurance_price_df.isnull().sum()
# Out:
# Policy no.        0
# age               0
# sex               0
# bmi               0
# charges in INR    0
# dtype: int64

# %%
# Visualizing the missing values
# Plot missing values matrix for personal_details dataset
plt.figure(figsize=(12,6))
sns.heatmap(personal_details_df.isnull(), cmap="viridis", cbar=False, yticklabels=False)
plt.title("Missing Values Heatmap - Personal_details Dataset")
plt.show()

# %%
# Plot missing values matrix for insurance_price dataset
plt.figure(figsize=(12,6))
sns.heatmap(insurance_price_df.isnull(), cmap="magma", cbar=False, yticklabels=False)
plt.title("Missing Values Heatmap - Insurance_price Dataset")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# After analyzing the dataset, here are the key observations:
#
# # 1. Dataset Overview
# The Personal Details dataset contains 1338 rows and 4 columns: Policy no., children, smoker, and region.
#
# The Insurance Price dataset contains 1338 rows and 5 columns: Policy no., age, sex, bmi, and charges in INR.
#
# Both datasets share Policy no., allowing them to be merged for deeper analysis.
#
# # 2. Missing Values Analysis
# There are no missing values in either dataset.
#
# This ensures data completeness and eliminates the need for imputation.
#
#
# # 3. Duplicate Values
# No duplicate rows are present in either dataset.
#
# This confirms that each policyholder is represented uniquely.
#
# # 4. Column Insights
# Categorical Columns: sex, smoker, and region. These will be useful for group-wise analysis.
#
# Numerical Columns: age, bmi, children, and charges in INR. These will be key for statistical analysis and visualizations.
#
# charges in INR represents the insurance claim amount, making it the primary target variable for understanding cost variations.
#
#
# # 5. Potential Insights from Analysis
# **Gender Impact:** Analyzing whether insurance costs vary between males and females.
#
# **Smoker vs. Non-Smoker:** Likely significant cost differences based on smoking status.
#
# **Age & BMI Impact:** Higher BMI or age might correlate with higher insurance costs.
#
# **Geographic Differences:** Potential regional differences in claim amounts.
#
# **Dependents Influence:** Checking if more children lead to higher claim amounts.
#
# **Potential Discounts:** Exploring if healthy individuals (normal BMI, non-smokers) can be offered reduced premiums.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
personal_details_df.columns
# Out:
# Index(['Policy no.', 'children', 'smoker', 'region'], dtype='object')

# %%
insurance_price_df.columns
# Out:
# Index(['Policy no.', 'age', 'sex', 'bmi', 'charges in INR'], dtype='object')

# %%
# Dataset Describe
personal_details_df.describe
# Out:
# <bound method NDFrame.describe of      Policy no.  children smoker     region
# 0     PLC157006         0     no  southwest
# 1     PLC157033         1     no  southwest
# 2     PLC157060         0     no  southwest
# 3     PLC157087         1     no  southwest
# 4     PLC157186         5     no  southwest
# ...         ...       ...    ...        ...
# 1333  PLC168400         1    yes  northeast
# 1334  PLC168436         0    yes  northeast
# 1335  PLC168634         2    yes  northeast
# 1336  PLC168652         0    yes  northeast
# 1337  PLC168787         0    yes  northeast
#
# [1338 rows x 4 columns]>

# %%
insurance_price_df.describe
# Out:
# <bound method NDFrame.describe of      Policy no.  age     sex     bmi  charges in INR
# 0     PLC156898   19  female  27.900     16884.92400
# 1     PLC156907   18    male  33.770      1725.55230
# 2     PLC156916   28    male  33.000      4449.46200
# 3     PLC156925   33    male  22.705     21984.47061
# 4     PLC156934   32    male  28.880      3866.85520
# ...         ...  ...     ...     ...             ...
# 1333  PLC168895   50    male  30.970     10600.54830
# 1334  PLC168904   18  female  31.920      2205.98080
# 1335  PLC168913   18  female  36.850      1629.83350
# 1336  PLC168922   21  female  25.800      2007.94500
# 1337  PLC168931   61  female  29.070     29141.36030
#
# [1338 rows x 5 columns]>

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **The Personal Details** Dataset consists of four key variables. The Policy no. is a unique identifier assigned to each policyholder. The children column represents the number of dependents covered under the insurance policy. The smoker column indicates whether the individual is a smoker, with values as "yes" or "no." Lastly, the region column specifies the geographic location of the policyholder, such as northwest or southeast.
#
# **The Insurance Price** Dataset includes five variables. The Policy no. is again used as a unique identifier to match records between datasets. The age column denotes the age of the policyholder in years. The sex column categorizes individuals as either "male" or "female." The bmi (Body Mass Index) column provides a numerical value representing body fat based on height and weight. The charges in INR column records the total insurance claim amount in Indian Rupees, which serves as the key metric for assessing policy costs.
#
# Categorical variables such as sex, smoker, and region are crucial for group-wise comparisons, while numerical variables like age, bmi, children, and charges in INR require statistical analysis to uncover patterns. The primary focus of the analysis will be on charges in INR to understand how different factors impact insurance costs.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for personal_details_df table.
for column in personal_details_df.columns:
    print(f"Unique values in {column}: {personal_details_df[column].nunique()}")
# Out:
# Unique values in Policy no.: 1338
# Unique values in children: 6
# Unique values in smoker: 2
# Unique values in region: 4

# %%
# Check Unique Values for insurance_price_df table.
for column in insurance_price_df.columns:
    print(f"Unique values in {column}: {insurance_price_df[column].nunique()}")
# Out:
# Unique values in Policy no.: 1338
# Unique values in age: 47
# Unique values in sex: 2
# Unique values in bmi: 548
# Unique values in charges in INR: 1337

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# merging the dataset

df = pd.merge(insurance_price_df, personal_details_df, on='Policy no.')
df.head()
# Out:
#   Policy no.  age     sex     bmi  charges in INR  children smoker     region
# 0  PLC156898   19  female  27.900     16884.92400         0    yes  southwest
# 1  PLC156907   18    male  33.770      1725.55230         1     no  southeast
# 2  PLC156916   28    male  33.000      4449.46200         3     no  southeast
# 3  PLC156925   33    male  22.705     21984.47061         0     no  northwest
# 4  PLC156934   32    male  28.880      3866.85520         0     no  northwest

# %%
# Convert categorical variables
df['smoker'] = df['smoker'].astype('category')
df['sex'] = df['sex'].astype('category')
df['region'] = df['region'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Policy no.      1338 non-null   object
#  1   age             1338 non-null   int64
#  2   sex             1338 non-null   category
#  3   bmi             1338 non-null   float64
#  4   charges in INR  1338 non-null   float64
#  5   children        1338 non-null   int64
#  6   smoker          1338 non-null   category
#  7   region          1338 non-null   category
# dtypes: category(3), float64(2), int64(2), object(1)
# memory usage: 56.8+ KB

# %%
# Outlier Detection and Removal
q1 = df['charges in INR'].quantile(0.25)
q3 = df['charges in INR'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
df = df[(df['charges in INR'] >= lower_bound) & (df['charges in INR'] <= upper_bound)]

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# # 1. Insurance Claims by Gender(Boxplot)

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='sex', y='charges in INR', data=df)
plt.title("Insurance Claims by Gender")
plt.xlabel("Gender")
plt.ylabel("Insurance Charges (INR)")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot is ideal to compare the distribution of insurance claims for males and females.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Males tend to have slightly higher claim amounts than females.
#
# There are outliers, suggesting some high-cost claims.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Gender does not seem to be a major factor in claim differences, so policies should remain uniform.

# %% [markdown]
# # 2. Average Insurance Claim per Region– Bar Chart

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x='region', y='charges in INR', data=df, estimator=np.mean)
plt.title("Average Insurance Claim per Region")
plt.xlabel("Region")
plt.ylabel("Average Claim (INR)")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot helps in comparing average claims across different geographic regions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# One region may have consistently higher claims, suggesting regional healthcare cost differences.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The company can consider region-based pricing models to adjust for cost variations.
#
# If one region has significantly higher claims, it could lead to higher premium rates in that area.

# %% [markdown]
# #3. Impact of Smoking on Insurance Claims (Violin plot)

# %%
import plotly.express as px

# Creating the violin plot
fig = px.violin(df, x="smoker", y="charges in INR", box=True, points="all",
                title="Impact of Smoking on Insurance Claims",
                labels={"smoker": "Smoker Status", "charges in INR": "Insurance Charges (INR)"},
                color="smoker")

# Show interactive chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A violin plot gives a clearer picture of the distribution compared to a traditional boxplot.
#
# It helps in understanding variability in insurance claims between smokers and non-smokers.
#
# The interactive nature allows for better user exploration.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Smokers have a much higher spread in insurance claims, indicating higher medical costs.
#
# The median insurance charge for smokers is significantly higher than for non-smokers.
#
# Some extreme high-value claims are mostly from smokers, showing that they are high-risk customers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight can help insurance companies justify charging higher premiums for smokers.
#
# It highlights the need for smoker-specific policies with preventive healthcare programs to reduce claim costs.
#
#
# This could also increase regulatory concerns if smoking-related premium differences are seen as unfair.

# %% [markdown]
# # 4. Relationship Between Age and Insurance Charges  (Scatterplot)

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='age', y='charges in INR', hue='smoker', data=df)
plt.title("Age vs. Insurance Charges")
plt.xlabel("Age")
plt.ylabel("Insurance Charges (INR)")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot shows the trend between age and insurance costs.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Older people generally have higher claim amounts.
#
# Smokers show an even steeper increase in charges.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Age-based premium adjustments can optimize pricing.
#
#
#
# Older individuals may find insurance unaffordable.

# %% [markdown]
# # 5. BMI vs. Claims

# %%
# 5. BMI vs. Claims
plt.figure(figsize=(8, 5))
sns.scatterplot(x='bmi', y='charges in INR', hue='smoker', data=df)
plt.title("BMI vs. Insurance Claims")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Helps visualize how BMI affects claim amounts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Higher BMI is linked to higher claims, especially for smokers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The company can introduce health-based discounts for maintaining BMI.
#
#
#
# Obesity-linked claims may increase healthcare costs over time.

# %% [markdown]
# # 6. Number of Dependents vs. Insurance Claims (Point Plot)

# %%
plt.figure(figsize=(8, 5))

# Interactive point plot
sns.pointplot(x='children', y='charges in INR', data=df, estimator=np.mean, color="blue", markers="o", linestyles="-")

# Titles and labels
plt.title("Number of Dependents vs. Average Claim")
plt.xlabel("Number of Children")
plt.ylabel("Average Insurance Charges (INR)")

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A point plot effectively shows trends in how the number of dependents affects insurance claims.
#
# The line connection helps visualize if there is a progressive increase or fluctuation in claims.
#
# It makes it easier to interpret variations compared to a static bar plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The average claim amount does not increase proportionally with the number of dependents.
#
# Having one or two dependents shows higher insurance claims, but the pattern is not strictly linear.
#
# Families with more dependents (3 or more) don’t necessarily claim significantly higher amounts, which could indicate family-based policies or lower coverage per person.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Helps identify if dependent-based pricing is justified in insurance plans.
#
# Could guide family discounts for larger families if claims do not rise exponentially with dependents.
#
# Could encourage offering customized family plans instead of per-person premium calculations.

# %% [markdown]
# #7. Distribution of Insurance Claims  (Histogram)

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['charges in INR'], bins=30, kde=True)
plt.title("Distribution of Insurance Claims")
plt.xlabel("Insurance Charges (INR)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram shows the overall distribution of claim amounts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most claims are on the lower end, but a few high-cost outliers exist.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Helps in risk assessment and premium adjustments.
#
#
#
# Outliers may indicate fraudulent claims or severe health risks.

# %% [markdown]
# # 8. Insurance Costs for Smokers vs. Non-Smokers by Region  (Donut Chart)

# %%
import matplotlib.pyplot as plt

# Summarizing total charges for smokers and non-smokers by region
region_smoker_cost = df.groupby(['region', 'smoker'])['charges in INR'].sum().unstack()

# Creating a subplot for a semi-pie (donut) chart
fig, ax = plt.subplots(figsize=(8, 5), subplot_kw={'aspect': 'equal'})

# Labels and data
labels = []
sizes = []

for region in region_smoker_cost.index:
    labels.append(f"{region} - Smoker")
    sizes.append(region_smoker_cost.loc[region, 'yes'])
    labels.append(f"{region} - Non-Smoker")
    sizes.append(region_smoker_cost.loc[region, 'no'])

# Colors for distinction
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99', '#c2c2f0', '#ffb3e6', '#c4e17f', '#76d7c4']

# Plotting
wedges, texts, autotexts = ax.pie(
    sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=colors,
    wedgeprops={'linewidth': 1, 'edgecolor': 'white'}
)

# Creating a donut-style appearance
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig.gca().add_artist(centre_circle)

# Adding a title
plt.title("Proportion of Insurance Costs for Smokers vs. Non-Smokers by Region")
plt.show()
# Out:
# <ipython-input-31-6839b2c54d5d>:4: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A donut chart clearly visualizes the proportion of total insurance costs claimed by smokers and non-smokers across different regions.
#
# It provides an easy comparison without excessive details.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Smokers contribute to a significantly higher share of insurance claims in every region.
#
# Some regions (e.g., Southeast or Northwest) might have a much higher smoker-related claim burden than others.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight justifies the need for higher premium rates for smokers.
#
# The company can target specific regions with anti-smoking incentives to reduce claim costs.
#
#
#
# If a particular region has a very high percentage of smoking-related claims, it may indicate higher health risks and increase overall policy costs.
#
# Customers from these regions may face premium hikes, potentially making policies less affordable.

# %% [markdown]
# # 9. Average Claim by BMI Category (Bar chart)

# %%
# Categorizing BMI into groups
bins = [0, 18.5, 24.9, 29.9, np.inf]
labels = ['Underweight', 'Normal', 'Overweight', 'Obese']
df['bmi_category'] = pd.cut(df['bmi'], bins=bins, labels=labels)

# Horizontal bar plot
plt.figure(figsize=(8, 5))
sns.barplot(y='bmi_category', x='charges in INR', data=df, estimator=np.mean)

# Titles and labels
plt.title("Average Claim by BMI Category")
plt.xlabel("Average Insurance Charges (INR)")
plt.ylabel("BMI Category")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Helps compare claims across BMI categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Obese individuals have the highest claim costs.
#
#
#
# The company can introduce BMI-based premium incentives.
#
#
#
# High obesity claims may require higher risk adjustments.

# %% [markdown]
# #10. Correlation Heatmap

# %%
# Selecting only numerical columns for correlation analysis
correlation_matrix = df[['age', 'bmi', 'children', 'charges in INR']].corr()

# Plotting the heatmap
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5, fmt=".2f")

# Adding a title
plt.title("Correlation Heatmap of Insurance Data")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap is an effective way to visualize the strength of relationships between numerical variables.
#
# The color gradient helps in quickly identifying strong and weak correlations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Charges are strongly correlated with age and BMI, meaning older and overweight individuals tend to have higher claim costs.
#
# Smoking is not included in this correlation map because it’s a categorical variable, but separate analysis already showed smokers have much higher claims.
#
# Children (number of dependents) has a weak correlation with charges, suggesting family size does not significantly impact claim costs.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1. Assess the Impact of Gender on Policy Extension
#
# 🔹 Finding: Gender does not have a significant impact on insurance claims.
#
# 🔹 Recommendation: Policies should not be differentiated based on gender. Instead, focus on other strong predictors like age, BMI, and smoking status.
#
# 2. Analyze the Average Cost per Policy Cover
#
# 🔹 Finding: The average claim amount is significantly impacted by BMI, smoking status, and age rather than gender or number of dependents.
#
# 🔹 Recommendation:
#
# Introduce tiered premium pricing based on high-risk factors like obesity and smoking.
#
# Provide wellness incentives for customers with healthy lifestyles to manage claim costs.
#
# 3. Determine the Need for Geographic-Based Policy Segmentation
#
# 🔹 Finding: Claims vary significantly across different regions, likely due to differences in healthcare costs, lifestyle, and risk factors.
#
# 🔹 Recommendation:
#
# Implement location-based pricing to account for regional healthcare cost differences.
#
# Conduct further region-wise risk profiling to fine-tune policies.
#
# 4. Evaluate the Effect of Dependents on Claim Amounts
#
# 🔹 Finding: The number of dependents has a weak correlation with claim amounts.
#
# 🔹 Recommendation:
#
# Maintain standard pricing models but consider family plans with discounts to attract more customers.
#
# If required, analyze deeper factors like family medical history instead of just the number of dependents.
#
# 5. Examine the Relationship Between BMI and Insurance Claims
#
# 🔹 Finding: Higher BMI is associated with increased insurance claims, likely due to obesity-related health issues.
#
# 🔹 Recommendation:
#
# Charge higher premiums for policyholders with high BMI while offering discounts for lower-risk individuals.
#
# Implement BMI-based health programs to encourage weight management and reduce long-term risk.
#
# 6. Assess the Importance of Smoking Status in Policy Pricing
#
# 🔹 Finding: Smokers have significantly higher insurance claims than non-smokers.
#
# 🔹 Recommendation:
#
# Higher premiums should be applied to smokers due to increased health risks.
#
# Consider incentives for quitting smoking, such as discounts for tobacco cessation programs.
#
# 7. Investigate Age as a Barrier in Insurance Claims
#
# 🔹 Finding: Older individuals tend to have significantly higher claim amounts due to age-related health risks.
#
# 🔹 Recommendation:
#
# Implement age-based premium adjustments to manage risks.
#
# Offer senior wellness plans to encourage preventive healthcare and reduce claims.
#
# 8. Explore the Possibility of Health-Based Discounts
#
# 🔹 Finding: Individuals with better health indicators (low BMI, non-smokers) have lower insurance claims.
#
# 🔹 Recommendation:
#
# Offer discounted premiums for individuals with good BMI, non-smokers, and active lifestyles.
#
# Introduce wellness engagement programs where customers earn discounts based on annual health checkups and fitness activities.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This analysis helped optimize insurance pricing and risk assessment for MediBuddy. Key findings show that smoking, high BMI, age, and geographic location significantly impact insurance claims, while gender and number of dependents have minimal effect.
#
#  Business Impact:
#
#  Risk-based pricing for smokers and high BMI individuals
#
#  Location-based premiums to reflect regional healthcare costs
#
#  Wellness incentives & discounts for healthier lifestyles
#
#  Optimized family and senior plans for better coverage
